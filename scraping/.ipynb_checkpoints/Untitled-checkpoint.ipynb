# %%
import pandas as pd

# %%
df1 = pd.read_csv('data-homes.csv')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df1
# Out:
#       Unnamed: 0                                            society      area  \
# 0            0.0                               in Sector 4, Gurgaon    160.00
# 1            1.0                               in Sector 4, Gurgaon    160.00
# 2            2.0                             in New Colony, Gurgaon    150.00
# 3            3.0                               in Sector 9, Gurgaon    342.00
# 4            4.0      in CGHS Airport Apartment, Sector 47, Gurgaon       NaN
# 5            5.0                            in DLF Phase 2, Gurgaon    500.00
# 6            6.0           in Block C, Sushant Lok Phase 1, Gurgaon     66.00
# 7            7.0           in Block C, Sushant Lok Phase 1, Gurgaon    540.00
# 8            8.0                            in DLF Phase 2, Gurgaon    215.00
# 9            9.0                             in New Colony, Gurgaon    210.00
# 10          10.0                             in New Colony, Gurgaon    102.00
# ...

# %%
# df1 = df1.drop(columns  = ['Unnamed: 0.1' ,	'Unnamed: 0' ,'index'])

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.to_csv('data-homes.csv')
