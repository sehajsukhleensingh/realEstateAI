# %%
import pandas as pd
import numpy as np 
import plotly as pt

# %%
pd.set_option('display.max.rows',None)
pd.set_option('display.max.columns',None)

# %%
dt = pd.read_csv('properties-cleaned-v5.csv')

# %%
dt['sector'].value_counts()
# Out:
# sector
# sector 65                          164
# sector 102                         139
# sector 43                          134
# sector 50                          116
# sector 109                         114
# sector 81                          112
# sector 66                           94
# sector 26                           93
# sector 49                           85
# sector 37                           85
# sector 23                           81
# sector 67                           78
# sector 1                            77
# sector 57                           77
# sector 108                          77
# sector 106                          76
# sector 82                           73
# sector 48                           69
# sector 86                           67
# sector 70                           62
# sector 104                          59
# sector 54                           58
# sector 107                          57
# sector 25                           57
# ...
